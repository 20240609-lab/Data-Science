# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Data-Science/blob/main/week06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #복습

# %%
bool[]
# Out:
# bool

# %%
a = [1,2,3,4]
a.append(5)
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = 'python'
b.find('t')
# Out:
# 2

# %%
c = {1:'a',2:'b',3:'c'}
c.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
d = {1,2,2,3}
d.add(4)
d
# Out:
# {1, 2, 3, 4}

# %%
e = (1,1,2,3)
e.count(1)
# Out:
# 2

# %% [markdown]
# 복습 문제

# %%
fruits = ['바나나','사과','포도','오렌지']
fruits[1] = '딸기'

fruits
# Out:
# ['바나나', '딸기', '포도', '오렌지']

# %%
num = '881120-1068234'
print(num[:6])
print(num[7:])

front = num[:6]
back = num[7:]
print(front)
print(back)

print(f'주민번호 앞자리는 {front} 이고, 뒷자리는 {back} 입니다.')
# Out:
# 881120
# 1068234
# 881120
# 1068234
# 주민번호 앞자리는 881120이고, 뒷자리는 1068234입니다.

# %%
scores = {'철수':80,'영희':75,'민수':90}
sum(scores.values())/len(scores)
# Out:
# 81.66666666666667

# %% [markdown]
# #**제어문**
# 1. if
# 2. = , > , <
# 3. in

# %%
for i in range(1, 6):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
i = input('점수를 입력해주세요. : ')

if(int(i) > 79):
  print('합격')
else:
  print('불합격')
# Out:
# 점수를 입력해주세요. : 60
# 불합격

# %%
money = 0

if money:
  print('택시 ㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 걷기 ㄱ

# %%
money = 5000

if money>3000:
  print('택시 ㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 택시 ㄱ

# %%
money = 2000
watch = 0
pet = 1

if money>=3000 or (watch and pet):
  print('택시 ㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 걷기 ㄱ

# %%
pocket = ['paper','phone','money']

if 'money' in pocket:
  print('택시 ㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 택시 ㄱ

# %%
pocket = ('paper','phone','money')

if 'money' not in pocket:
  print('택시 ㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 걷기 ㄱ

# %%
price = 999

if(price>=1000):
  print('할인이 적용됨.')
else:
  print('할인이 적용되지않음.')
# Out:
# 할인이 적용되지않음.

# %%
num = input('숫자를 입력해주세요. : ')

if(int(num)%2==0):
  print('짝수')
else:
  print('홀수')
# Out:
# 숫자를 입력해주세요. : 4
# 짝수

# %%
review = '이 강의가 제일 좋아'

if(len(review)>=10):
  print('정상')

else:
  print('비정상')
# Out:
# 정상

# %%
pocket = ['paper','phone','money']
watch = 0

if 'money' not in pocket:
  print('택시 ㄱ')
else:
  if watch:
    print('택시 ㄱㄱ')

  else:
    print('걷기 ㄱ')
# Out:
# 걷기 ㄱ

# %%
pocket = ['paper','phone','money']
watch = 0

if 'money' not in pocket:
  print('택시 ㄱ')
elif watch:
  print('택시 ㄱㄱ')
else:
  print('걷기 ㄱ')
# Out:
# 걷기 ㄱ

# %%
age = 22

if age>=19:
  print('성인입니다.')
elif 13<=age<19:
  print('청소년입니다.')
else:
  print("어린이입니다.")
# Out:
# 성인입니다.

# %%
score = 85

if 90<=score<=100:
  print('A')

elif 80<=score<=89:
  print('B')

elif 70<=score<=79:
  print('C')

elif 60<=score<=69:
  print('D')

else:
  print('F')
# Out:
# B

# %%
review = '이 수업 너무 지겨워!'

if '수업' in review:
  review = review.replace('수업', '강의')
if '지겨워' in review:
  review = review.replace('지겨워', '즐거워')

else:
  print('정상')

print(review)
# Out:
# 이 강의 너무 즐거워!

# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Data-Science/blob/main/week04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #데이터 사이언스 2026년 3월 26일 4주차

# %%
사과 = 1
print(사과)

apple = 2
print(apple)
# Out:
# 1
# 2

# %%
if = 1
for = 2
1 = 'a'
#문법 오류
# Out:
#   File "/tmp/ipykernel_4550/2440659864.py", line 1
#     if = 1
#        ^
# SyntaxError: invalid syntax

# %%
int_num = 123
type(int_num)
# Out:
# int

# %%
float_num = 3.14
type(float_num)
# Out:
# float

# %%
fruit = 'apple'
type(fruit)
# Out:
# str

# %%
fruit = "banana'
# Out:
#   File "/tmp/ipykernel_4550/3416005786.py", line 1
#     fruit = "banana'
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str_num = "123"
type(str_num)
# Out:
# str

# %%
result = True
type(result)
# Out:
# bool

# %%
result = TRUE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4550/2805490431.py in <cell line: 0>()
# ----> 1 result = TRUE
#
# NameError: name 'TRUE' is not defined

# %%
print('나는 "파이썬"이 참 좋다.')
# Out:
# 나는 "파이썬"이 참 좋다.

# %%
print("월\t화\t수\t목\t금\n")
print("1\t2\t3\t4\t5\n")
# Out:
# 월	화	수	목	금
#
# 1	2	3	4	5

# %%
'''
가나다라마바사
'''
#주석

print(123)
# Out:
# 123

# %%
# 연습 문제 1
# 1. 100 = int
# 2. 3.14 = float
# 3. "100" = str
# 4. True = bool

# 연습 문제 2
# str = 2,3,5
# Out:
# '\n연습 문제 1 \n1. 100 = int\n2. 3.14 = float\n3. "100" = str\n4. True = bool\n\n연습 문제 2\nstr = 2,3,5\n'

# %%
for i in range(1, 6):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(50):
  if i%2 == 0:
    print(i, '숫자는 짝수입니다.')
  else:
    print(i,'숫자는 홀수입니다..')
# Out:
# 0 숫자는 짝수입니다.
# 1 숫자는 홀수입니다..
# 2 숫자는 짝수입니다.
# 3 숫자는 홀수입니다..
# 4 숫자는 짝수입니다.
# 5 숫자는 홀수입니다..
# 6 숫자는 짝수입니다.
# 7 숫자는 홀수입니다..
# 8 숫자는 짝수입니다.
# 9 숫자는 홀수입니다..
# 10 숫자는 짝수입니다.
# 11 숫자는 홀수입니다..
# 12 숫자는 짝수입니다.
# 13 숫자는 홀수입니다..
# 14 숫자는 짝수입니다.
# 15 숫자는 홀수입니다..
# 16 숫자는 짝수입니다.
# 17 숫자는 홀수입니다..
# 18 숫자는 짝수입니다.
# 19 숫자는 홀수입니다..
# 20 숫자는 짝수입니다.
# 21 숫자는 홀수입니다..
# 22 숫자는 짝수입니다.
# 23 숫자는 홀수입니다..
# 24 숫자는 짝수입니다.
# 25 숫자는 홀수입니다..
# 26 숫자는 짝수입니다.
# 27 숫자는 홀수입니다..
# 28 숫자는 짝수입니다.
# 29 숫자는 홀수입니다..
# 30 숫자는 짝수입니다.
# 31 숫자는 홀수입니다..
# 32 숫자는 짝수입니다.
# 33 숫자는 홀수입니다..
# 34 숫자는 짝수입니다.
# 35 숫자는 홀수입니다..
# 36 숫자는 짝수입니다.
# 37 숫자는 홀수입니다..
# 38 숫자는 짝수입니다.
# 39 숫자는 홀수입니다..
# 40 숫자는 짝수입니다.
# 41 숫자는 홀수입니다..
# 42 숫자는 짝수입니다.
# 43 숫자는 홀수입니다..
# 44 숫자는 짝수입니다.
# 45 숫자는 홀수입니다..
# 46 숫자는 짝수입니다.
# 47 숫자는 홀수입니다..
# 48 숫자는 짝수입니다.
# 49 숫자는 홀수입니다..

# %%
a = 100
a += 10
a
# Out:
# 110

# %%
a = 100
a = a + 10
a
# Out:
# 110

# %%
a = 11
a*=11
a
# Out:
# 121

# %%
a = [30,20,10]
a[0] = 100
a[1:3] = [200,300]

a
# Out:
# [100, 200, 300]

# %%
10 == 10
100 != 10
# Out:
# True

# %%
a = 10
b = 20

x = a > 1 and b > 2  #Ture and Ture
y = a > 1 or b < 2 #True or Flase
z = not a > 100 #True


print(x,y,z)
# Out:
# True True True

# %%
not (" ") #비어있는게 Ture / 0 = Flase
# Out:
# False

# %%
3 >= 2 and 4 > 3 and 10 < 2
# Out:
# False

# %%
# 연습문제 3
# 10 == 10 True
# 10 != 5 True
# 3 > 7 Flase
# 8 <= 8 True

# 연습문제 4
# 10 > 5 and 3 > 1 Ture
# 10 > 5 and 3 < 1 Flase
# 10 > 5 or 3 < 1 Ture
# not 5 > 3 Flase

# %%
print("현재 온도는 %d도 입니다."%18)
print("현재 온도는 %s도 입니다.\n"%19)

print("I can eat %s apples."%"three")
print("I can eat %d apples."%3)
print("I can eat %0.2f apples.\n"%3.14)
print("%s apples and %s banana"%(3,4))
# Out:
# 현재 온도는 18도 입니다.
# 현재 온도는 19도 입니다.
#
# I can eat three apples.
# I can eat 3 apples.
# I can eat 3.14 apples.
#
# 3 apples and 4 banana

# %%
print("I can eat {} apples.".format(3))
print("I can eat {} apples.".format("five"))
print("I can eat {} apples.".format(3.14))
print("I ate {} apples {}.".format(3, "yesterday"))
# Out:
# I can eat 3 apples.
# I can eat five apples.
# I can eat 3.14 apples.
# I ate 3 apples yesterday.

# %%
name = '홍길동'
age = 30

print(f'나의 이름은 {name}입니다. 나이는 {age}입니다.')
# Out:
# 나의 이름은 홍길동입니다. 나이는 30입니다.

# %% [markdown]
# ##컬렉션 자료형
# list

# %%
a = []
type(a)

b = [1,2,3]
c = ['life','is','too','hard']
d = [1,2,'life','is']
e = [1,2,['life','is']]

# %%
a = 'python'
a[4]
# Out:
# 'o'

# %%
a = 'Python is Fun!'
a[10:13]
# Out:
# 'Fun'

# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Data-Science/blob/main/review1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 데이터 분석 개요 및 실습환경

# %%
#Q1. 아래와 같이 두 줄이 출력되도록 코드를 작성하세요.
#파이썬
#재밌어요

print('파이썬')
print('재밌어요')
# Out:
# 파이썬
# 재밌어요

# %%
#Q2. 아래와 같이 출력되도록 코드를 작성하세요.
#*
#**
#***
#****
#*****

print('*')
print('**')
print('***')
print('****')
print('*****')

for i in range(1,6):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# *
# **
# ***
# ****
# *****

# %%
#Q3. 가로가 5, 세로가 3인 직사각형의 넓이를 구해 출력하세요.
5*3
# Out:
# 15

# %%
#Q4. 반지름이 4인 원의 둘레를 구해 출력하세요.
2*3.14*4
# Out:
# 25.12

# %% [markdown]
# #2. 데이터분석을 위한 파이썬1

# %% [markdown]
# 연습문제 1
# - 다음 문제의 자료형을 쓰세요.
#
# 100 = int
#
# 3.14 = float
#
# -'100' = str
#
# True = bool
#
#
# -  다음 중 문자열인 것만 모두 고르세요.
# 1. 123
# 2. '123'
# 3. 'python'
# 4. False
# 5. 'False'
#
# 2,3,5

# %% [markdown]
# 연습문제 2
# - 다음 비교 연산의 결과를 각각 쓰세요.
#
# 10 == 10 = Ture
#
# 10 != 5 = Ture
#
# 3 > 7 = False
#
# 8 <= 8 = Ture
#
# - 다음 논리 연산의 결과를 쓰세요.
#
# 10 > 5 and 3 > 1 = Ture
#
# 10 > 5 and 3 < 1 = False
#
# 10 > 5 or 3 < 1 = Ture
#
# not 5 > 3 = False

# %%
#연습문제 3
a = [10,20,30,40]
print(a[0])
print(a[2])
print(a[-1])
# Out:
# 10
# 30
# 40

# %%
a = [10,20,30,40,50]
print(a[1:4])
print(a[:3])
print(a[2:])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]

# %%
a = [1,2,3]
a.append(4)

a
# Out:
# [1, 2, 3, 4]

# %%
student = {'name':'철수','age':20}
student['name']
# Out:
# '철수'

# %% [markdown]
# #3. 데이터분석을 위한 파이썬2

# %%
#Review 1
#다음 리스트에서 '사과'를 '딸기'로 변경하고 출력하세요.
fruits = ['바나나','사과','포도','오렌지']
fruits[1] = '딸기'

fruits
# Out:
# ['바나나', '딸기', '포도', '오렌지']

# %%
#홍길동 씨의 주민등록번호는 '881120-1068234'이다. 슬라이싱을 이용하여 홍길동씨의 주민등록번호를 연월일(YYYYMMDD)부분과 그 뒤의 숫자부분으로 나누어 출력하라.
num = '881120-1068234'


print(num[:6])
print(num[7:])
# Out:
# 881120
# 1068234

# %%
#다음 학생들의 점수가 저장된 딕셔너리에서 모든 학생의 평균 점수를 구하여 출력하시오.
scores = {'철수':80,'영희':75,'민수':90}

sum(scores.values())/len(scores)
# Out:
# 81.66666666666667

# %% [markdown]
# 연습문제 1
# - 가격이 1000원 이상이면, '할인이 적용됩니다.' 그렇지 않으면 '할인이 적용되지 않습니다.'

# %%
price = 999

if price>=1000:
  print('할인이 적용됩니다.')
else:
  print('할인이 적용되지 않습니다.')
# Out:
# 할인이 적용되지 않습니다.

# %% [markdown]
# 연습문제 2
# - 임의의 자연수를 갖는 number가 주어졌을 때, 짝수이면 '짝수입니다.' 홀수이면 '홀수입니다.'

# %%
number = 2


if number%2==0:
  print('짝수입니다.')
else:
  print('홀수입니다.')
# Out:
# 짝수입니다.

# %% [markdown]
# 연습문제 3
# - review = '이 강의가 제일 좋아!'일때, review에 들어있는 글자 수가 10개 이상이면, '정상 리뷰입니다.' 그렇지 않으면 '비정상 리뷰입니다.'

# %%
review = '이 강의가 제일 좋아!'

if len(review)>=10:
  print('정상 리뷰입니다.')
else:
  print('비정상 리뷰입니다.')
# Out:
# 정상 리뷰입니다.

# %% [markdown]
# 연습문제 1
# - 나이가 19 이상이면, '성인입니다.'
#
# - 나이가 13 이상 19 미만이면, '청소년입니다.'
#
# -  나이가 13 미만이면, '어린이입니다.'

# %%
age = 22

if age >= 19:
  print('성인입니다.')
elif 19 < age <= 13:
  print('청소년입니다.')
else:
  print('어린이입니다.')
# Out:
# 성인입니다.

# %% [markdown]
# 연습문제 2
# - score = 85
#
# 시험점수가 100점 만점 중, 90~100점은 A
#
# 80~89점은 B
#
# 70~79점은 C
#
# 60~69점은 D
#
# 나머지는 F

# %%
score = 85
grade = ''

if 90 <= score <= 100:
  grade = 'A'
elif 80 <= score < 90:
  grade = 'B'
elif 70 <= score < 80:
  grade = 'C'
elif 60 <= score < 70:
  grade = 'D'
else:
  grade = 'F'

print(f'당신의 점수는 {score}점이므로, {grade}입니다.')
# Out:
# 당신의 점수는 85점이므로, B입니다.

# %% [markdown]
# 연습문제 3
# - review = '이 수업 너무 지겨워!'라는 문자열이 있을 때,
#
# 만약 '수업'이라는 단어가 등장하면, '강의'로, '지겨워'라는 단어가 등장하면, '즐거워'로 변경

# %%
review = '이 수업 너무 지겨워!'

if '수업' in review:
  review = review.replace('수업','강의')
if '지겨워' in review:
  review = review.replace('지겨워','즐거워')
else:
  print('정상 리뷰입니다.')

print(review)
# Out:
# 이 강의 너무 즐거워!

# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Data-Science/blob/main/review2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###2_데이터분석을 위한 파이썬1

# %% [markdown]
# 자료형
#
# - 숫자형, 문자열, 참과 거짓
# - 리스트, 튜플, 딕셔너리, 집합

# %% [markdown]
# 연산자
# - 산술 연산자 (+, -, *, /, %, **, //)
# - 대입 연산자 (=, +=, -=, *=, /=, %=, **=, //=)
# - 비교 연산자 (==, !=, >, >=, <, <=)
# - 논리 연산자 (and, or, not)

# %% [markdown]
# 문자열 포매팅

# %%
print("I can eat %s apples." % "three")
print("I can eat {0} applews {1}".format(3,"yesterday"))

name = '홍길동'
age = 30
print(f'나의 이름은 {name}입니다. 나이는 {age}입니다.')
# Out:
# I can eat three apples.
# I can eat 3 applews yesterday
# 나의 이름은 홍길동입니다. 나이는 30입니다.

# %% [markdown]
# 컬렉션 자료형
# - 리스트 []
# - 튜플 ()
# - 딕셔너리 {:}
# - 세트 {}

# %% [markdown]
# 리스트
#
# - 인덱싱
#
# - 리스트 슬라이싱
# - 값 변경
# - 함수
#
#
# append() : 리스트에 요소를 마지막 위치에 새로 추가
#
# len() : 리스트 총 요소 개수를 반환

# %% [markdown]
# 튜플
# - 저장된 값 수정불가
# - 인덱싱 & 슬라이싱

# %% [markdown]
# 딕셔너리
# - key & value
#
# items() 딕셔너리에 저장된 모든 키와 값 반환
#
# key() 딕셔너리에 저장된 모든 키 반환
#
# values() 딕셔너리에 저장된 모든 값 반환

# %% [markdown]
# 세트
# - 중복을 허용하지않음
# - 인뎅싱 & 슬라이싱 x

# %%
student = {"name": "철수", "age" : 20}
student["name"]
# Out:
# '철수'

# %%
scores = {'철수':80,'영희':75,'민수':90}
sum(scores.values())/len(scores)
# Out:
# 81.66666666666667

# %% [markdown]
# ###3_데이터분석을 위한 파이썬2

# %% [markdown]
# 제어문
# - 조건문
# - 반복문

# %% [markdown]
# 20260409

# %% [markdown]
# ###4_데이터분석을 위한 파이썬3

# %% [markdown]
# 반복문
# - for문
# - 중첩 for문

# %% [markdown]
# 리스트 내포
#
# 20260430

# %% [markdown]
# ###5_데이터분석을 위한 파이썬4

# %% [markdown]
# - 함수
# - 예외처리

# %% [markdown]
# 20260507

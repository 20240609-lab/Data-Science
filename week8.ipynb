# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Data-Science/blob/main/week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = "Lotte World"

print(word[6:8])
# Out:
# Wo

# %%
a = [30,20,10]
a[0] = 100
a[1:3] = [200,300]

a
# Out:
# [100, 200, 300]

# %% [markdown]
# #리스트 제어 함수

# %%
a = [1,2,3]
b = [4,5,6]

a.append(4)
print(a)

b.append([7,8])
print(b)
# Out:
# [1, 2, 3, 4]
# [4, 5, 6, [7, 8]]

# %%
x = [20,10,30]

x.sort()
print(x)

x.reverse()
print(x)
# Out:
# [10, 20, 30]
# [30, 20, 10]

# %%
print('love'.capitalize())
# Out:
# Love

# %%
len(['a','b'])
# Out:
# 2

# %%
a = [1,2,3]
a.append(4) ##추가하다. str
print(a)
b = [1,2,3]
b.extend([4,5]) ##확장하다. only list
print(b)

c =[1,2,3]
##c.extend(4) type error 리스트 형식으로 써야한다.
print(c)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5]
# [1, 2, 3]

# %% [markdown]
# #tuple

# %%
a = ()
type(a)

z = (1,2,3)
print(z)

xyz = (1,2,3,3)
xyz.count(3)
# Out:
# (1, 2, 3)
# 2

# %%
z[0]
# Out:
# 1

# %% [markdown]
# #dict

# %%
null_dict = {}
null_dict
# Out:
# {}

# %%
menu = {'김밥':2000,'라면':3000,'돈가스':5000}
menu
# Out:
# {'김밥': 2000, '라면': 3000, '돈가스': 5000}

# %%
type(menu)
# Out:
# dict

# %%
menu['김밥']
# Out:
# 2000

# %%
menu['김밥'] = 3000
menu
# Out:
# {'김밥': 3000, '라면': 3000, '돈가스': 5000}

# %%
menu.items()
# Out:
# dict_items([('김밥', 3000), ('라면', 3000), ('돈가스', 5000)])

# %% [markdown]
# 연습문제 3
# 10
# 30
# 40
#
# 20 30 40 /
# 10 20 30 /
# 30 40 50

# %%
a = [1,2,3]
a.append(4)

a
# Out:
# [1, 2, 3, 4]

# %%
student = {"name": "철수", "age" : 20}
student["name"]
# Out:
# '철수'

# %%
for i in range(2, 10):
  for j in range(1,10):
    print(i*j, end=' ')
  print('\n')
#★★★★ 시험 or 퀴즈 ★★★★
# Out:
# 2 4 6 8 10 12 14 16 18
#
# 3 6 9 12 15 18 21 24 27
#
# 4 8 12 16 20 24 28 32 36
#
# 5 10 15 20 25 30 35 40 45
#
# 6 12 18 24 30 36 42 48 54
#
# 7 14 21 28 35 42 49 56 63
#
# 8 16 24 32 40 48 56 64 72
#
# 9 18 27 36 45 54 63 72 81

# %%
for i in range(1,6):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
